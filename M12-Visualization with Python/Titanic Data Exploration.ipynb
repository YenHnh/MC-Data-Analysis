# %% [markdown]
# ## Titanic Data Exploration ##
#
# ***
#
# Over the past several weeks, you've learned the code about how to explore and manipulate a dataset. Now it's time to practice what you've learned on a real-world dataset.
#
# ***
#
# ### Titanic Dataset
#
# The titanic dataset holds information about the passengers on the titanic. This includes passenger name, characteristics, and if they survived the accident. The dataset has the following columns:
#
#     * pclass = passenger class; 1 = first class, 2 = second class, 3 = third class
#     * survived = passenger survival; 1 = survived, 0 = did not survive
#     * name = passenger name
#     * sex = sex of passenger
#     * age = age of passenger
#     * sibsp = # of siblings / spouses aboard the Titanic
#     * parch = # of parents / children aboard the Titanic
#     * ticket = ticket number
#     * fare = fare paid by passenger
#     * cabin = passenger cabin
#     * embarked = port of embarkation; C = Cherbourg, Q = Queenstown, S = Southampton
#     * boat = lifeboat assignment
#     * body = recovered body number
#     * home dest = anticipated home destination
#
# If you need some additional motivation before starting, please visit: https://www.youtube.com/watch?v=3gK_2XdjOdY
#
# ### How to work through the dataset:
#
# Follow the prompts below to explore, manipulate, and visualize aspects of the dataset. Working with data takes time, so take your time as you start with a messy dataset and turn it into something that shows meaningful visualizations.
#
# ***

# %% [markdown]
# ### Import Libraries and Dataset
#
# * Review the entire notebook to determine what you will be expected to do - then, import the necessary libraries
# * Import the titanic.xlsx dataset

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as sm
import scipy.stats as stats

# %%
df = pd.read_excel("titanic.xlsx")
df.head(50)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# 19       1         0                               Beattie, Mr. Thomson
# 20       1         1                      Beckwith, Mr. Richard Leonard
# 21       1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22       1         1                              Behr, Mr. Karl Howell
# 23       1         1                              Bidois, Miss. Rosalie
# 24       1         1                                  Bird, Miss. Ellen
# 25       1         0                                Birnbaum, Mr. Jakob
# 26       1         1                            Bishop, Mr. Dickinson H
# 27       1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28       1         1                             Bissette, Miss. Amelia
# 29       1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 30       1         0                       Blackwell, Mr. Stephen Weart
# 31       1         1                                   Blank, Mr. Henry
# 32       1         1                            Bonnell, Miss. Caroline
# 33       1         1                           Bonnell, Miss. Elizabeth
# 34       1         0                           Borebank, Mr. John James
# 35       1         1                           Bowen, Miss. Grace Scott
# 36       1         1                        Bowerman, Miss. Elsie Edith
# 37       1         1      Bradley, Mr. George ("George Arthur Brayton")
# 38       1         0                            Brady, Mr. John Bertram
# 39       1         0                                 Brandeis, Mr. Emil
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 41       1         1          Brown, Mrs. James Joseph (Margaret Tobin)
# 42       1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 43       1         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 44       1         1                    Burns, Miss. Elizabeth Margaret
# 45       1         0                  Butt, Major. Archibald Willingham
# 46       1         0                              Cairns, Mr. Alexander
# 47       1         1                  Calderhead, Mr. Edward Pennington
# 48       1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 49       1         1                 Cardeza, Mr. Thomas Drake Martinez
#
#        sex      age  sibsp  parch    ticket      fare        cabin embarked  \
# 0   female  29.0000      0      0     24160  211.3375           B5        S
# 1     male   0.9167      1      2    113781  151.5500      C22 C26        S
# 2   female   2.0000      1      2    113781  151.5500      C22 C26        S
# 3     male  30.0000      1      2    113781  151.5500      C22 C26        S
# 4   female  25.0000      1      2    113781  151.5500      C22 C26        S
# 5     male  48.0000      0      0     19952   26.5500          E12        S
# 6   female  63.0000      1      0     13502   77.9583           D7        S
# 7     male  39.0000      0      0    112050    0.0000          A36        S
# 8   female  53.0000      2      0     11769   51.4792         C101        S
# 9     male  71.0000      0      0  PC 17609   49.5042          NaN        C
# 10    male  47.0000      1      0  PC 17757  227.5250      C62 C64        C
# 11  female  18.0000      1      0  PC 17757  227.5250      C62 C64        C
# 12  female  24.0000      0      0  PC 17477   69.3000          B35        C
# 13  female  26.0000      0      0     19877   78.8500          NaN        S
# 14    male  80.0000      0      0     27042   30.0000          A23        S
# 15    male      NaN      0      0  PC 17318   25.9250          NaN        S
# 16    male  24.0000      0      1  PC 17558  247.5208      B58 B60        C
# 17  female  50.0000      0      1  PC 17558  247.5208      B58 B60        C
# 18  female  32.0000      0      0     11813   76.2917          D15        C
# 19    male  36.0000      0      0     13050   75.2417           C6        C
# 20    male  37.0000      1      1     11751   52.5542          D35        S
# 21  female  47.0000      1      1     11751   52.5542          D35        S
# 22    male  26.0000      0      0    111369   30.0000         C148        C
# 23  female  42.0000      0      0  PC 17757  227.5250          NaN        C
# 24  female  29.0000      0      0  PC 17483  221.7792          C97        S
# 25    male  25.0000      0      0     13905   26.0000          NaN        C
# 26    male  25.0000      1      0     11967   91.0792          B49        C
# 27  female  19.0000      1      0     11967   91.0792          B49        C
# 28  female  35.0000      0      0  PC 17760  135.6333          C99        S
# 29    male  28.0000      0      0    110564   26.5500          C52        S
# 30    male  45.0000      0      0    113784   35.5000            T        S
# 31    male  40.0000      0      0    112277   31.0000          A31        C
# 32  female  30.0000      0      0     36928  164.8667           C7        S
# 33  female  58.0000      0      0    113783   26.5500         C103        S
# 34    male  42.0000      0      0    110489   26.5500          D22        S
# 35  female  45.0000      0      0  PC 17608  262.3750          NaN        C
# 36  female  22.0000      0      1    113505   55.0000          E33        S
# 37    male      NaN      0      0    111427   26.5500          NaN        S
# 38    male  41.0000      0      0    113054   30.5000          A21        S
# 39    male  48.0000      0      0  PC 17591   50.4958          B10        C
# 40    male      NaN      0      0    112379   39.6000          NaN        C
# 41  female  44.0000      0      0  PC 17610   27.7208           B4        C
# 42  female  59.0000      2      0     11769   51.4792         C101        S
# 43  female  60.0000      0      0     11813   76.2917          D15        C
# 44  female  41.0000      0      0     16966  134.5000          E40        C
# 45    male  45.0000      0      0    113050   26.5500          B38        S
# 46    male      NaN      0      0    113798   31.0000          NaN        S
# 47    male  42.0000      0      0  PC 17476   26.2875          E24        S
# 48  female  53.0000      0      0  PC 17606   27.4458          NaN        C
# 49    male  36.0000      0      1  PC 17755  512.3292  B51 B53 B55        C
#
#    boat   body                                       home.dest
# 0     2    NaN                                    St Louis, MO
# 1    11    NaN                 Montreal, PQ / Chesterville, ON
# 2   NaN    NaN                 Montreal, PQ / Chesterville, ON
# 3   NaN  135.0                 Montreal, PQ / Chesterville, ON
# 4   NaN    NaN                 Montreal, PQ / Chesterville, ON
# 5     3    NaN                                    New York, NY
# 6    10    NaN                                      Hudson, NY
# 7   NaN    NaN                                     Belfast, NI
# 8     D    NaN                             Bayside, Queens, NY
# 9   NaN   22.0                             Montevideo, Uruguay
# 10  NaN  124.0                                    New York, NY
# 11    4    NaN                                    New York, NY
# 12    9    NaN                                   Paris, France
# 13    6    NaN                                             NaN
# 14    B    NaN                                   Hessle, Yorks
# 15  NaN    NaN                                    New York, NY
# 16  NaN    NaN                                    Montreal, PQ
# 17    6    NaN                                    Montreal, PQ
# 18    8    NaN                                             NaN
# 19    A    NaN                                    Winnipeg, MN
# 20    5    NaN                                    New York, NY
# 21    5    NaN                                    New York, NY
# 22    5    NaN                                    New York, NY
# 23    4    NaN                                             NaN
# 24    8    NaN                                             NaN
# 25  NaN  148.0                               San Francisco, CA
# 26    7    NaN                                    Dowagiac, MI
# 27    7    NaN                                    Dowagiac, MI
# 28    8    NaN                                             NaN
# 29    D    NaN              Stockholm, Sweden / Washington, DC
# 30  NaN    NaN                                     Trenton, NJ
# 31    7    NaN                                  Glen Ridge, NJ
# 32    8    NaN                                  Youngstown, OH
# 33    8    NaN               Birkdale, England Cleveland, Ohio
# 34  NaN    NaN                           London / Winnipeg, MB
# 35    4    NaN                                 Cooperstown, NY
# 36    6    NaN                St Leonards-on-Sea, England Ohio
# 37    9    NaN                                 Los Angeles, CA
# 38  NaN    NaN                                     Pomeroy, WA
# 39  NaN  208.0                                       Omaha, NE
# 40  NaN    NaN                                Philadelphia, PA
# 41    6    NaN                                      Denver, CO
# 42    D    NaN                                     Belmont, MA
# 43    8    NaN                                Philadelphia, PA
# 44    3    NaN                                             NaN
# 45  NaN    NaN                                  Washington, DC
# 46  NaN    NaN                                             NaN
# 47    5    NaN                                    New York, NY
# 48    6    NaN                                  Washington, DC
# 49    3    NaN  Austria-Hungary / Germantown, Philadelphia, PA

# %% [markdown]
# ### Determine the Characteristics of the Dataset
#
#    * How many columns are in this dataset?
#    * How many rows are in this dataset?
#    * What types of data are in each column? Does this make sense with that you know about that column?
#    * Which variables are numeric? Which variables are categorical? What other variables are left outside of these two groups?
#    * Which variable could be considered a 'dependent' variable?

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pclass             1309 non-null   object
#  1   survived           1309 non-null   object
#  2   name               1309 non-null   object
#  3   sex                1309 non-null   object
#  4   age                1046 non-null   float64
#  5   sibsp              1309 non-null   int64
#  6   parch              1309 non-null   int64
#  7   ticket             1309 non-null   object
#  8   fare               1308 non-null   float64
#  9   embarked           1307 non-null   object
#  10  Titanic Passenger  1309 non-null   int64
#  11  Family Size        1309 non-null   int64
#  12  Travel Alone       1309 non-null   int64
#  13  Has Caregiver      1309 non-null   int64
#  14  Crew               1309 non-null   int64
#  15  Age Group          1046 non-null   category
# dtypes: category(1), float64(2), int64(7), object(6)
# memory usage: 155.0+ KB

# %%
#df["IMDB rating"] = df["IMDB rating"].astype(int)
#df["ticket"] = df["ticket"].astype(float)

# %%
#pclass	survived	name	sex	age	sibsp	parch	ticket	fare	cabin	embarked	boat	body	home.dest
#catogerical/qualitative
df["pclass"].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
#catogerical/qualitative
df["survived"].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
#
df["sibsp"].value_counts()
# Out:
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: sibsp, dtype: int64

# %%
#catogerical/qualitative
df["sex"].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df["parch"].value_counts()
# Out:
# 0    1002
# 1     170
# 2     113
# 3       8
# 4       6
# 5       6
# 6       2
# 9       2
# Name: parch, dtype: int64

# %%
#neither
df["ticket"].value_counts()
# Out:
# CA. 2343    11
# 1601         8
# CA 2144      8
# PC 17608     7
# 347077       7
#             ..
# 244373       1
# 211535       1
# 373450       1
# 345783       1
# 2223         1
# Name: ticket, Length: 939, dtype: int64

# %%
#neither
df["fare"].value_counts()
# Out:
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
#            ..
# 6.2375      1
# 7.7417      1
# 28.5375     1
# 12.6500     1
# 10.7083     1
# Name: fare, Length: 281, dtype: int64

# %%
#neither
df["cabin"].value_counts()
# Out:
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# C78                4
# F4                 4
#                   ..
# C111               1
# B52 B54 B56        1
# C47                1
# B42                1
# B4                 1
# Name: cabin, Length: 186, dtype: int64

# %%
#catogerical/qualitative
df["embarked"].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
#neither
df["cabin"].value_counts()
# Out:
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# C78                4
# F4                 4
#                   ..
# C111               1
# B52 B54 B56        1
# C47                1
# B42                1
# B4                 1
# Name: cabin, Length: 186, dtype: int64

# %%
#neither
df["boat"].value_counts()
# Out:
# 13         39
# C          38
# 15         37
# 14         33
# 4          31
# 10         29
# 5          27
# 3          26
# 11         25
# 9          25
# 8          23
# 7          23
# 16         23
# 6          20
# D          20
# 12         19
# 2          12
# A          11
# B           9
# 1           5
# 13 15       2
# 5 7         2
# C D         2
# 13 15 B     1
# 8 10        1
# 5 9         1
# 15 16       1
# 2           1
# Name: boat, dtype: int64

# %%
#neither
df["body"].value_counts()
# Out:
# 255.0    1
# 249.0    1
# 189.0    1
# 142.0    1
# 261.0    1
#         ..
# 37.0     1
# 327.0    1
# 295.0    1
# 269.0    1
# 122.0    1
# Name: body, Length: 121, dtype: int64

# %%
#neither
df["home.dest"].value_counts()
# Out:
# New York, NY                      64
# London                            14
# Montreal, PQ                      10
# Cornwall / Akron, OH               9
# Paris, France                      9
#                                   ..
# Co Sligo, Ireland New York, NY     1
# Surbiton Hill, Surrey              1
# East Bridgewater, MA               1
# Hamilton, ON                       1
# Myren, Sweden New York, NY         1
# Name: home.dest, Length: 369, dtype: int64

# %% [markdown]
# ### Identify the Missing Data in the Dataset
#
#    * Is there any missing data?
#    * Which columns have any missing data?
#    * Which column has the most missing information? Which column has the least?

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
#Which columns have any missing data?
#age, fare, cabin, embarked, boat, body, home.dest

# %%
#Which column has the most missing information? Which column has the least?
# most: body; least: fare

# %% [markdown]
# ### Handling the Missing Data in the Dataset
#
#    * Remove the columns with excessive missing data (any column missing greater than 500 rows)
#    * When there is very little missing data, we can make replacements. Replace the missing data for the "embarked" column with the most common embarkation point.
#    * Replace the missing data in "fare" with the average fare of the entire sample.
#    * Remove the rows in the dataset that has missing "age" data.
#    * Recheck is there is any data missing in the dataset.

# %%
#cabin, boat, body, home.dest
df.drop(columns = "cabin", inplace = True)

# %%
df.drop(columns = "boat", inplace = True)

# %%
df.drop(columns = "body", inplace = True)

# %%
df.drop(columns = "home.dest", inplace = True)

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# 0     female  29.0000      0      0   24160  211.3375        S
# 1       male   0.9167      1      2  113781  151.5500        S
# 2     female   2.0000      1      2  113781  151.5500        S
# 3       male  30.0000      1      2  113781  151.5500        S
# 4     female  25.0000      1      2  113781  151.5500        S
# ...      ...      ...    ...    ...     ...       ...      ...
# 1304  female  14.5000      1      0    2665   14.4542        C
# 1305  female      NaN      1      0    2665   14.4542        C
# 1306    male  26.5000      0      0    2656    7.2250        C
# 1307    male  27.0000      0      0    2670    7.2250        C
# 1308    male  29.0000      0      0  315082    7.8750        S
#
# [1309 rows x 10 columns]

# %% [markdown]
# ### Creating Columns and Replacing Labels
#
#    * Create descriptive labels for the categorical columns: pclass, survived, and embarked. Instead of the coding that shows in the dataset, create labels to describe what each category represents (i.e. in the embarked column S = Southhampton)
#    * Create a new column called "Titanic Passenger" and make all values 1
#    * Create a new column called "Family Size" - this column should equal the total number of family members each passenger was traveling with.
#    * Create a column called "Travel Alone" - this column should be 1 if the passenger was traveling alone, and 0 if the passenger was traveling with family.
#    * Create a column called "Has Caregiver" - this column should have a value of 1 if a passenger is less than 13-years old AND the passenger is traveling with at least one family member, otherwise the value should be 0.
#    * Create a column called "Crew" - this column should be 1 if the passenger paid 0 dollars for their ticket, and 0 otherwise.
#    * Create a column called "Age Group" to group passengers by their age (create five categories: infant, child, teen, adult, senior). You can use bins to complete this (or any other method you like). You define the cutoff points for each group you create.
#
# After create new columns, replace the basic coding "0/1" with meaningful labels.

# %% [markdown]
#  pclass = passenger class; 1 = first class, 2 = second class, 3 = third class
# * survived = passenger survival; 1 = survived, 0 = did not survive
# * name = passenger name
# * sex = sex of passenger
# * age = age of passenger
# * sibsp = # of siblings / spouses aboard the Titanic
# * parch = # of parents / children aboard the Titanic
# * ticket = ticket number
# * fare = fare paid by passenger
# * cabin = passenger cabin
# * embarked = port of embarkation; C = Cherbourg, Q = Queenstown, S = Southampton
# * boat = lifeboat assignment
# * body = recovered body number
# * home dest = anticipated home destination

# %%
#Create descriptive labels for the categorical columns: pclass, survived, and embarked. 
#Instead of the coding that shows in the dataset, 
#create labels to describe what each category represents (i.e. in the embarked column S = Southhampton)
#baby["parity"].replace([0, 1], ["No", "Yes"], inplace = True)
df["pclass"].replace([1,2,3],["First class","Second class","Third class"],inplace = True)
df
# Out:
#            pclass  survived                                             name  \
# 0     First class         1                    Allen, Miss. Elisabeth Walton
# 1     First class         1                   Allison, Master. Hudson Trevor
# 2     First class         0                     Allison, Miss. Helen Loraine
# 3     First class         0             Allison, Mr. Hudson Joshua Creighton
# 4     First class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1304  Third class         0                             Zabour, Miss. Hileni
# 1305  Third class         0                            Zabour, Miss. Thamine
# 1306  Third class         0                        Zakarian, Mr. Mapriededer
# 1307  Third class         0                              Zakarian, Mr. Ortin
# 1308  Third class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# 0     female  29.0000      0      0   24160  211.3375        S
# 1       male   0.9167      1      2  113781  151.5500        S
# 2     female   2.0000      1      2  113781  151.5500        S
# 3       male  30.0000      1      2  113781  151.5500        S
# 4     female  25.0000      1      2  113781  151.5500        S
# ...      ...      ...    ...    ...     ...       ...      ...
# 1304  female  14.5000      1      0    2665   14.4542        C
# 1305  female      NaN      1      0    2665   14.4542        C
# 1306    male  26.5000      0      0    2656    7.2250        C
# 1307    male  27.0000      0      0    2670    7.2250        C
# 1308    male  29.0000      0      0  315082    7.8750        S
#
# [1309 rows x 10 columns]

# %%
df["survived"].replace([0,1],["Did not survive","Survived"],inplace = True)
df
# Out:
#            pclass         survived  \
# 0     First class         Survived
# 1     First class         Survived
# 2     First class  Did not survive
# 3     First class  Did not survive
# 4     First class  Did not survive
# ...           ...              ...
# 1304  Third class  Did not survive
# 1305  Third class  Did not survive
# 1306  Third class  Did not survive
# 1307  Third class  Did not survive
# 1308  Third class  Did not survive
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare embarked
# 0         0   24160  211.3375        S
# 1         2  113781  151.5500        S
# 2         2  113781  151.5500        S
# 3         2  113781  151.5500        S
# 4         2  113781  151.5500        S
# ...     ...     ...       ...      ...
# 1304      0    2665   14.4542        C
# 1305      0    2665   14.4542        C
# 1306      0    2656    7.2250        C
# 1307      0    2670    7.2250        C
# 1308      0  315082    7.8750        S
#
# [1309 rows x 10 columns]

# %%
df["embarked"].replace(["C","Q","S"],["Cherbourg","Queenstown","Southampton"],inplace = True)
df
# Out:
#            pclass         survived  \
# 0     First class         Survived
# 1     First class         Survived
# 2     First class  Did not survive
# 3     First class  Did not survive
# 4     First class  Did not survive
# ...           ...              ...
# 1304  Third class  Did not survive
# 1305  Third class  Did not survive
# 1306  Third class  Did not survive
# 1307  Third class  Did not survive
# 1308  Third class  Did not survive
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked
# 0         0   24160  211.3375  Southampton
# 1         2  113781  151.5500  Southampton
# 2         2  113781  151.5500  Southampton
# 3         2  113781  151.5500  Southampton
# 4         2  113781  151.5500  Southampton
# ...     ...     ...       ...          ...
# 1304      0    2665   14.4542    Cherbourg
# 1305      0    2665   14.4542    Cherbourg
# 1306      0    2656    7.2250    Cherbourg
# 1307      0    2670    7.2250    Cherbourg
# 1308      0  315082    7.8750  Southampton
#
# [1309 rows x 10 columns]

# %%
df["Titanic Passenger"] = 1
df
# Out:
#            pclass         survived  \
# 0     First class         Survived
# 1     First class         Survived
# 2     First class  Did not survive
# 3     First class  Did not survive
# 4     First class  Did not survive
# ...           ...              ...
# 1304  Third class  Did not survive
# 1305  Third class  Did not survive
# 1306  Third class  Did not survive
# 1307  Third class  Did not survive
# 1308  Third class  Did not survive
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked  Titanic Passenger
# 0         0   24160  211.3375  Southampton                  1
# 1         2  113781  151.5500  Southampton                  1
# 2         2  113781  151.5500  Southampton                  1
# 3         2  113781  151.5500  Southampton                  1
# 4         2  113781  151.5500  Southampton                  1
# ...     ...     ...       ...          ...                ...
# 1304      0    2665   14.4542    Cherbourg                  1
# 1305      0    2665   14.4542    Cherbourg                  1
# 1306      0    2656    7.2250    Cherbourg                  1
# 1307      0    2670    7.2250    Cherbourg                  1
# 1308      0  315082    7.8750  Southampton                  1
#
# [1309 rows x 11 columns]

# %%
df["Family Size"] = df["sibsp"] + df["parch"] +1
df
# Out:
#            pclass         survived  \
# 0     First class         Survived
# 1     First class         Survived
# 2     First class  Did not survive
# 3     First class  Did not survive
# 4     First class  Did not survive
# ...           ...              ...
# 1304  Third class  Did not survive
# 1305  Third class  Did not survive
# 1306  Third class  Did not survive
# 1307  Third class  Did not survive
# 1308  Third class  Did not survive
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked  Titanic Passenger  Family Size
# 0         0   24160  211.3375  Southampton                  1            1
# 1         2  113781  151.5500  Southampton                  1            4
# 2         2  113781  151.5500  Southampton                  1            4
# 3         2  113781  151.5500  Southampton                  1            4
# 4         2  113781  151.5500  Southampton                  1            4
# ...     ...     ...       ...          ...                ...          ...
# 1304      0    2665   14.4542    Cherbourg                  1            2
# 1305      0    2665   14.4542    Cherbourg                  1            2
# 1306      0    2656    7.2250    Cherbourg                  1            1
# 1307      0    2670    7.2250    Cherbourg                  1            1
# 1308      0  315082    7.8750  Southampton                  1            1
#
# [1309 rows x 12 columns]

# %%
#Create a column called "Travel Alone" - 
#this column should be 1 if the passenger was traveling alone, 
#and 0 if the passenger was traveling with family.
#df["Honor_Role"] = np.where(((df["Pass_Fail"] == "Passed") & (df["Grades"] > 89)), 1, 0)
df["Travel Alone"] = np.where((df["Family Size"] == 1), 1, 0)
df
# Out:
#            pclass         survived  \
# 0     First class         Survived
# 1     First class         Survived
# 2     First class  Did not survive
# 3     First class  Did not survive
# 4     First class  Did not survive
# ...           ...              ...
# 1304  Third class  Did not survive
# 1305  Third class  Did not survive
# 1306  Third class  Did not survive
# 1307  Third class  Did not survive
# 1308  Third class  Did not survive
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked  Titanic Passenger  Family Size  \
# 0         0   24160  211.3375  Southampton                  1            1
# 1         2  113781  151.5500  Southampton                  1            4
# 2         2  113781  151.5500  Southampton                  1            4
# 3         2  113781  151.5500  Southampton                  1            4
# 4         2  113781  151.5500  Southampton                  1            4
# ...     ...     ...       ...          ...                ...          ...
# 1304      0    2665   14.4542    Cherbourg                  1            2
# 1305      0    2665   14.4542    Cherbourg                  1            2
# 1306      0    2656    7.2250    Cherbourg                  1            1
# 1307      0    2670    7.2250    Cherbourg                  1            1
# 1308      0  315082    7.8750  Southampton                  1            1
#
#       Travel Alone
# 0                1
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 1304             0
# 1305             0
# 1306             1
# 1307             1
# 1308             1
#
# [1309 rows x 13 columns]

# %%
#Create a column called "Has Caregiver" - 
#this column should have a value of 1 if a passenger is less than 13-years old 
#AND the passenger is traveling with at least one family member, otherwise the value should be 0.
df["Has Caregiver"] = np.where((df["age"] < 13) & (df["Family Size"] > 1), 1, 0)
df
# Out:
#            pclass         survived  \
# 0     First class         Survived
# 1     First class         Survived
# 2     First class  Did not survive
# 3     First class  Did not survive
# 4     First class  Did not survive
# ...           ...              ...
# 1304  Third class  Did not survive
# 1305  Third class  Did not survive
# 1306  Third class  Did not survive
# 1307  Third class  Did not survive
# 1308  Third class  Did not survive
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked  Titanic Passenger  Family Size  \
# 0         0   24160  211.3375  Southampton                  1            1
# 1         2  113781  151.5500  Southampton                  1            4
# 2         2  113781  151.5500  Southampton                  1            4
# 3         2  113781  151.5500  Southampton                  1            4
# 4         2  113781  151.5500  Southampton                  1            4
# ...     ...     ...       ...          ...                ...          ...
# 1304      0    2665   14.4542    Cherbourg                  1            2
# 1305      0    2665   14.4542    Cherbourg                  1            2
# 1306      0    2656    7.2250    Cherbourg                  1            1
# 1307      0    2670    7.2250    Cherbourg                  1            1
# 1308      0  315082    7.8750  Southampton                  1            1
#
#       Travel Alone  Has Caregiver
# 0                1              0
# 1                0              1
# 2                0              1
# 3                0              0
# 4                0              0
# ...            ...            ...
# 1304             0              0
# 1305             0              0
# 1306             1              0
# 1307             1              0
# 1308             1              0
#
# [1309 rows x 14 columns]

# %%
#Create a column called "Crew" - 
#this column should be 1 if the passenger paid 0 dollars for their ticket, and 0 otherwise.
df["Crew"] = np.where(df["fare"] == 0, 1, 0)
df
# Out:
#            pclass         survived  \
# 0     First class         Survived
# 1     First class         Survived
# 2     First class  Did not survive
# 3     First class  Did not survive
# 4     First class  Did not survive
# ...           ...              ...
# 1304  Third class  Did not survive
# 1305  Third class  Did not survive
# 1306  Third class  Did not survive
# 1307  Third class  Did not survive
# 1308  Third class  Did not survive
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked  Titanic Passenger  Family Size  \
# 0         0   24160  211.3375  Southampton                  1            1
# 1         2  113781  151.5500  Southampton                  1            4
# 2         2  113781  151.5500  Southampton                  1            4
# 3         2  113781  151.5500  Southampton                  1            4
# 4         2  113781  151.5500  Southampton                  1            4
# ...     ...     ...       ...          ...                ...          ...
# 1304      0    2665   14.4542    Cherbourg                  1            2
# 1305      0    2665   14.4542    Cherbourg                  1            2
# 1306      0    2656    7.2250    Cherbourg                  1            1
# 1307      0    2670    7.2250    Cherbourg                  1            1
# 1308      0  315082    7.8750  Southampton                  1            1
#
#       Travel Alone  Has Caregiver  Crew
# 0                1              0     0
# 1                0              1     0
# 2                0              1     0
# 3                0              0     0
# 4                0              0     0
# ...            ...            ...   ...
# 1304             0              0     0
# 1305             0              0     0
# 1306             1              0     0
# 1307             1              0     0
# 1308             1              0     0
#
# [1309 rows x 15 columns]

# %%
#Create a column called "Age Group" to group passengers by their age 
#(create five categories: infant, child, teen, adult, senior). 
#You can use bins to complete this (or any other method you like). 
#You define the cutoff points for each group you create.

bins = [0, 1, 10, 18, 50, 150]
bin_labels = ["Infant", "Child", "Teen", "Adult", "Senior"]
df["Age Group"] = pd.cut(df["age"], bins, labels = bin_labels)
df
# Out:
#            pclass         survived  \
# 0     First class         Survived
# 1     First class         Survived
# 2     First class  Did not survive
# 3     First class  Did not survive
# 4     First class  Did not survive
# ...           ...              ...
# 1304  Third class  Did not survive
# 1305  Third class  Did not survive
# 1306  Third class  Did not survive
# 1307  Third class  Did not survive
# 1308  Third class  Did not survive
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked  Titanic Passenger  Family Size  \
# 0         0   24160  211.3375  Southampton                  1            1
# 1         2  113781  151.5500  Southampton                  1            4
# 2         2  113781  151.5500  Southampton                  1            4
# 3         2  113781  151.5500  Southampton                  1            4
# 4         2  113781  151.5500  Southampton                  1            4
# ...     ...     ...       ...          ...                ...          ...
# 1304      0    2665   14.4542    Cherbourg                  1            2
# 1305      0    2665   14.4542    Cherbourg                  1            2
# 1306      0    2656    7.2250    Cherbourg                  1            1
# 1307      0    2670    7.2250    Cherbourg                  1            1
# 1308      0  315082    7.8750  Southampton                  1            1
#
#       Travel Alone  Has Caregiver  Crew Age Group
# 0                1              0     0     Adult
# 1                0              1     0    Infant
# 2                0              1     0     Child
# 3                0              0     0     Adult
# 4                0              0     0     Adult
# ...            ...            ...   ...       ...
# 1304             0              0     0      Teen
# 1305             0              0     0       NaN
# 1306             1              0     0     Adult
# 1307             1              0     0     Adult
# 1308             1              0     0     Adult
#
# [1309 rows x 16 columns]

# %% [markdown]
# ### Determine Frequencies of Groups
#
# * How many passengers fall into each category? Determine how many passengers fall into each group for <b>each</b> categorical vairable (including the ones you just created).

# %%
df["pclass"].value_counts()
# Out:
# Third class     709
# First class     323
# Second class    277
# Name: pclass, dtype: int64

# %%
df["survived"].value_counts()
# Out:
# Did not survive    809
# Survived           500
# Name: survived, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df["embarked"].value_counts()
# Out:
# Southampton    914
# Cherbourg      270
# Queenstown     123
# Name: embarked, dtype: int64

# %%
df["Travel Alone"].value_counts()
# Out:
# 1    790
# 0    519
# Name: Travel Alone, dtype: int64

# %%
df["Has Caregiver"].value_counts()
# Out:
# 0    1218
# 1      91
# Name: Has Caregiver, dtype: int64

# %%
df["Crew"].value_counts()
# Out:
# 0    1292
# 1      17
# Name: Crew, dtype: int64

# %%
df["Age Group"].value_counts()
# Out:
# Adult     758
# Teen      107
# Senior     95
# Child      64
# Infant     22
# Name: Age Group, dtype: int64

# %% [markdown]
# ### Determine the Distribution of Numeric Data
#
# * What are the summary statistics for <b>each</b> numeric variable in the dataset? Summary statistics include:
#     * Mean
#     * Median
#     * Mode
#     * Standard Deviation
#     * Range

# %%
#Age, fare, 
print("Age's mean: ", df["age"].mean())
print("Age's median: ", df["age"].median())
print("Age's mode: ", df["age"].mode())
print("Age's standard deviation: ", df["age"].std())
print("Age's range: ", df['age'].max() - df['age'].min())
# Out:
# Age's mean:  29.8811345124283
# Age's median:  28.0
# Age's mode:  0    24.0
# dtype: float64
# Age's standard deviation:  14.413499699923594
# Age's range:  79.8333

# %%
print("Fare's mean: ", df["fare"].mean())
print("Fare's median: ", df["fare"].median())
print("Fare's mode: ", df["fare"].mode())
print("Fare's standard deviation: ", df["fare"].std())
print("Fare's range: ", df['fare'].max() - df['fare'].min())
# Out:
# Fare's mean:  33.29547928134572
# Fare's median:  14.4542
# Fare's mode:  0    8.05
# dtype: float64
# Fare's standard deviation:  51.758668239174135
# Fare's range:  512.3292

# %% [markdown]
# ### Relationships between Variables
#
# * Determine the relationship between each variable and the variable "survived". This is our primary variable of interest -- did this passenger survive the accident? Did the characteristics of the passenger have any relationship with their survival?
#     * <b>pclass</b>: how many survivors are in each passenger class? does a pattern emerge? which class has the most survivors? which has the least?
#     * <b>sex</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>age</b>: how does the average age of the passenger differ based on survival group?
#     * <b>age group</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>family size</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>travel alone</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>crew</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>has caregiver</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>fare</b>: how does the average fare the passenger paid differ based on survival group?
#     * <b>embarked</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#
# Based on what you learn working through this section, make (2) statements about what characteristics of passenger most influenced their survival.

# %%
## Two qualitative variables
# independent variable

pd.crosstab(df["survived"], df["pclass"], margins = True)
# Out:
# pclass           First class  Second class  Third class   All
# survived
# Did not survive          123           158          528   809
# Survived                 200           119          181   500
# All                      323           277          709  1309

# %%
# independent variable
pd.crosstab(df["survived"], df["sex"], margins = True)
# Out:
# sex              female  male   All
# survived
# Did not survive     127   682   809
# Survived            339   161   500
# All                 466   843  1309

# %%
# independent variable
pd.crosstab(df["survived"], df["Age Group"], margins = True)
# Out:
# Age Group        Infant  Child  Teen  Adult  Senior   All
# survived
# Did not survive       5     31    62    464      57   619
# Survived             17     33    45    294      38   427
# All                  22     64   107    758      95  1046

# %%
pd.crosstab(df["survived"], df["Travel Alone"], margins = True)
# Out:
# Travel Alone       0    1   All
# survived
# Did not survive  258  551   809
# Survived         261  239   500
# All              519  790  1309

# %%
pd.crosstab(df["survived"], df["Crew"], margins = True)
# Out:
# Crew                0   1   All
# survived
# Did not survive   794  15   809
# Survived          498   2   500
# All              1292  17  1309

# %%
pd.crosstab(df["survived"], df["Has Caregiver"], margins = True)
# Out:
# Has Caregiver       0   1   All
# survived
# Did not survive   770  39   809
# Survived          448  52   500
# All              1218  91  1309

# %%
# independent variable

pd.crosstab(df["survived"], df["embarked"], margins = True)
# Out:
# embarked         Cherbourg  Queenstown  Southampton   All
# survived
# Did not survive        120          79          610   809
# Survived               150          44          304   498
# All                    270         123          914  1307

# %%
## One qualitative variable, one numeric

df["age"].groupby(df["survived"]).mean()
# Out:
# survived
# Did not survive    30.545369
# Survived           28.918228
# Name: age, dtype: float64

# %%
# independent variable
df["fare"].groupby(df["survived"]).mean()
# Out:
# survived
# Did not survive    23.353831
# Survived           49.361184
# Name: fare, dtype: float64

# %% [markdown]
# ### Visualize your Results
#
# * Using the most interesting (from your POV) results from the above section, create (3) visualizations to illustrate the results.
# * Create a barplot to show the variation in average age across passenger class. On average, which passenger class has the oldest passengers?
# * Create a violin plot to show the distribution of age across passenger class.

# %%
### matplotlib.pyplot is a 2D plotting library that creates high-quality figures

from matplotlib import pyplot as plt

### this command allows you to view your plots in the notebook

# %matplotlib inline

### seaborn is complimentary to matplotlib and allows for further plot customization 

import seaborn as sns

# %%
## creating a simple count plot showing most of the passengers didn't survive

sns.countplot(data = df, x = "survived")
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
# show correlation of stats via heatmap
plt.figure(figsize=(7,7))

# calculate the correlation matrix for the numeric dataset 
corr = df.corr()

# plot a heat map to show the magnitude of the correlation between variables
sns.heatmap(corr, vmin = -1, annot = True)
# Out:
# <AxesSubplot:>

# %%
# Relationship between ages and fares
plt.figure(figsize=(18,5))

sns.regplot(x = df["age"], y = df["fare"], fit_reg = True)

plt.grid()

# %%
#Create a barplot to show the variation in average age across passenger class. 
#On average, which passenger class has the oldest passengers?

sns.barplot(data = df, x = "pclass", y = "age", ci = None)

### change the axis labels

plt.xticks(ticks = [0,1,2], labels = ["First class", "Second class", "Third class"])

### change the axis labels

plt.xlabel("Passenger Classes")
plt.ylabel("Age")

### add title and grid lines
plt.title('Age Statistic by Passenger Classes')
plt.grid()

# %%
### Create a violin plot to show the distribution of age across passenger class.

sns.violinplot(x = df["pclass"], y = df["age"])
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>
